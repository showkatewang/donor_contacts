# %%
# import packages
import pandas as pd

# %%
# files to load, direct path
hospitality_to_load = "Resources/Growjo-industry-Hospitality.csv"

# %%
# alterative indirect path method
import os
hospitality1_to_load = os.path.join("Resources", "Growjo-industry-Hospitality.csv")

# %%
# read file and store in dataframe
hospitality_df = pd.read_csv(hospitality_to_load)
hospitality_df
# Out:
#                    company_name                   url       city state  \
# 0                          Mews              mews.com     London   NaN
# 1    Playa Largo Resort and Spa          marriott.com  Key Largo    FL
# 2              The Westin Tempe          marriott.com      Tempe    AZ
# 3                     Frontdesk     stayfrontdesk.com  Milwaukee    WI
# 4                    Life House   lifehousehotels.com   New York    NY
# ..                          ...                   ...        ...   ...
# 80            Ultima Collection  ultimacollection.com     Genève   NaN
# 81                  OTA Insight        otainsight.com     London   NaN
# 82                The Hosteller      thehosteller.com     Mumbai   NaN
# 83  Van der Valk Hotel Schiedam      hotelschiedam.nl   Schiedam   NaN
# 84                       Minoan  minoanexperience.com   New York    NY
#
#           country  employees  \
# 0              UK        692
# 1   United States         66
# ...

# %%
# show non-truncated column info
pd.set_option('display.max_columns', None) 
hospitality_df.head(10)
# Out:
#                                company_name  \
# 0                                      Mews
# 1                Playa Largo Resort and Spa
# 2                          The Westin Tempe
# 3                                 Frontdesk
# 4                                Life House
# 5  Circus Circus Las Vegas Hotel and Casino
# 6                                 Groups360
# 7                                   Getaway
# 8                                 Cloudbeds
# 9      Women Leading Travel and Hospitality
#
#                                     url          city state        country  \
# 0                              mews.com        London   NaN             UK
# 1                          marriott.com     Key Largo    FL  United States
# 2                          marriott.com         Tempe    AZ  United States
# 3                     stayfrontdesk.com     Milwaukee    WI  United States
# 4                   lifehousehotels.com      New York    NY  United States
# ...

# %%
# view number and content of any unique cells in column "contact_into"
hospitality_df.contact_info.unique()
# Out:
# array(['For Contact Direct Phone Numbers and Emails see Lead411'],
#       dtype=object)

# %%
# see rows 5 - 10
hospitality_df.loc[5:10]
# Out:
#                                 company_name  \
# 4                                 Life House
# 5   Circus Circus Las Vegas Hotel and Casino
# 6                                  Groups360
# 7                                    Getaway
# 8                                  Cloudbeds
# 9       Women Leading Travel and Hospitality
# 10                              Hotel Engine
#
#                                      url          city state        country  \
# 4                    lifehousehotels.com      New York    NY  United States
# 5                       circuscircus.com     Las Vegas    NV  United States
# 6                          Groups360.com     Brentwood    TN  United States
# 7                          getaway.house      Brooklyn    NY  United States
# 8                          cloudbeds.com     San Diego    CA  United States
# 9   womenleadingtravelandhospitality.com  Philadelphia    PA  United States
# ...

# %%
# See Circus Circus LinkedIn_URL in row 5
hospitality_df.loc[5, 'linkedin_url']
# Out:
# 'http://www.linkedin.com/company/circus-circus-las-vegas-hotel-and-casino'

# %%
# See full LinkedIn_URL cells
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
hospitality_df.iloc[:, [0, 1, 6]]
# Out:
#                                 company_name  \
# 0                                       Mews
# 1                 Playa Largo Resort and Spa
# 2                           The Westin Tempe
# 3                                  Frontdesk
# 4                                 Life House
# 5   Circus Circus Las Vegas Hotel and Casino
# 6                                  Groups360
# 7                                    Getaway
# 8                                  Cloudbeds
# 9       Women Leading Travel and Hospitality
# 10                              Hotel Engine
# 11                            The Social Hub
# 12                 Oneida Nation Enterprises
# 13                             blueground co
# 14                                    Cabana
# 15                          The Office Group
# 16                    TOG (The Office Group)
# 17                                     Domio
# 18                               Common Desk
# 19                                 Melt Shop
# ...
